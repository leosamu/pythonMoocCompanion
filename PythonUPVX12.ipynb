# %% [markdown]
# #Funcion type

# %%
type(1234)

# %%
type(55.50)

# %%
type(6+4j)

# %%
type("hello")

# %%
type([1,2,3,4])

# %%
type((1,2,3,4))

# %%
type({1:"one", 2:"two", 3:"three"})

# %% [markdown]
# #Funcion help()

# %%
help(int)

# %%
help(str)

# %%
help(dict)

# %% [markdown]
# #Función dir()

# %%
dir(int)

# %% [markdown]
# #Funciones de conversión

# %%
help(ord)

# %%
numerosEnTexto = "345"

# %%
3+ numerosEnTexto

# %%
3+ float(numerosEnTexto)

# %% [markdown]
# #Funcion input

# %%
edadDelUsuario = input("dime tu edad")

# %%
type(edadDelUsuario)
