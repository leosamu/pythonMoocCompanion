# %% [markdown]
# ## Errores de sintaxis

# %%
print("hola mundo"

# %%
print "hola mundo"

# %%
Print("hola mundo")

# %%
a = 034

# %%
"hola mundo" 34 34.6

# %%
print("esto va")
  print("esto no")

# %% [markdown]
# ## Errores de ejecución

# %%
3/0

# %%
a = "hola" + 2

# %%
archivo = open("error.txt","r")

# %%
a = [1,2,3,4]

b = a[6]
