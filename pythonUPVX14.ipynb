# %% [markdown]
# #Operaciones lógicas

# %%
tres = 3
cinco = 5

# %% [markdown]
# Comparadores

# %%
tres>cinco

# %%
tres>=cinco

# %%
tres<cinco

# %%
tres<=cinco

# %%
tres == cinco # no confundir con tres = cinco

# %%
"aa" is "a"*2

# %%
letraA = "a"
"aa" is letraA * 2

# %% [markdown]
# Conectores lógicos

# %%
verdadero=True
falso=False

# %%
verdadero and falso

# %%
verdadero or falso

# %%
not verdadero
